# %%
import spacy

# %%
import textacy
from bs4 import BeautifulSoup
from glob import glob
from collections import Counter

# %%
nlp = spacy.load('en_core_web_lg')

# %%
# %ls corpus-joyce-ulysses-tei
# Out:
# analysis/             u01_telemachus.xml*       u11_sirens.xml*
# CONTRIBUTING.md       u02_nestor.xml*           u12_cyclops.xml*
# cross-references.xml  u03_proteus.xml*          u13_nausica.xml*
# header.xml            u04_calypso.xml*          u14_oxen.xml*
# Makefile              u05_lotus-eaters.xml*     u15_circe.xml*
# persons.txt           u06_hades.xml*            u16_eumaeus.xml*
# public/               u07_aeolus.xml*           u17_ithaca.xml*
# README.md             u08_lestrygonians.xml*    u18_penelope.xml*
# schema/               u09_scylla.xml*
# stylesheets/          u10_wandering_rocks.xml*

# %%
episodesRaw = [open(f).read()[1:] for f in sorted(glob('corpus-joyce-ulysses-tei/u*.xml'))]

# %%
episodesRaw[0][:500]
# Out:
# '<div type="episode" n="01">\n<p rend="inset"><lb n="010000"/>I</p>\n<p><lb n="010001"/>Stately, plump Buck Mulligan came from the stairhead, bearing a\n<lb n="010002"/>bowl of lather on which a mirror and a razor lay crossed. A yellow\n<lb n="010003"/>dressinggown, ungirdled, was sustained gently behind him on the mild\n<lb n="010004"/>morning air. He held the bowl aloft and intoned:\n<lb n="010005"/><said who="bm">―<quote xml:lang="la">Introibo ad altare Dei.</quote></said></p>\n<p><lb n="010006"/>Hal'

# %%
# Extract the raw text from the XML.
episodesText = [BeautifulSoup(e, features='xml').get_text() for e in episodesRaw]

# %%
episodesText[0][:500]
# Out:
# '\nI\nStately, plump Buck Mulligan came from the stairhead, bearing a\nbowl of lather on which a mirror and a razor lay crossed. A yellow\ndressinggown, ungirdled, was sustained gently behind him on the mild\nmorning air. He held the bowl aloft and intoned:\n―Introibo ad altare Dei.\nHalted, he peered down the dark winding stairs and called out\ncoarsely:\n―Come up, Kinch! Come up, you fearful jesuit!\nSolemnly he came forward and mounted the round gunrest. He faced\nabout and blessed gravely thrice the tow'

# %%
e1doc = nlp(episodesText[0])

# %%
e1trigrams = textacy.extract.ngrams(e1doc, 7, filter_stops=False, filter_nums=True)

# %%
e1trigramsStr = [ngram.text for ngram in list(e1trigrams)]

# %%
Counter(e1trigramsStr).most_common()
# Out:
# [('graveclothes giving off an odour of wax', 2),
#  ('giving off an odour of wax and', 2),
#  ('off an odour of wax and rosewood', 2),
#  ("won't we have a merry time", 2),
#  ('plump Buck Mulligan came from the stairhead', 1),
#  ('bowl of lather on which a mirror', 1),
#  ('of lather on which a mirror and', 1),
#  ('lather on which a mirror and a', 1),
#  ('on which a mirror and a razor', 1),
#  ('which a mirror and a razor lay', 1),
#  ('a mirror and a razor lay crossed', 1),
#  ('was sustained gently behind him on the', 1),
#  ('sustained gently behind him on the mild', 1),
#  ('He held the bowl aloft and intoned', 1),
#  ('he peered down the dark winding stairs', 1),
#  ('peered down the dark winding stairs and', 1),
#  ('down the dark winding stairs and called', 1),
#  ('the dark winding stairs and called out', 1),
#  ('Solemnly he came forward and mounted the', 1),
#  ('he came forward and mounted the round', 1),
#  ('came forward and mounted the round gunrest', 1),
#  ('about and blessed gravely thrice the tower', 1),
#  ('towards him and made rapid crosses in', 1),
#  ('him and made rapid crosses in the', 1),
#  ('and made rapid crosses in the air', 1),
#  ('on the top of the staircase and', 1),
#  ('the top of the staircase and looked', 1),
#  ('top of the staircase and looked coldly', 1),
#  ('of the staircase and looked coldly at', 1),
#  ('the staircase and looked coldly at the', 1),
#  ('staircase and looked coldly at the shaking', 1),
#  ('and looked coldly at the shaking gurgling', 1),
#  ('looked coldly at the shaking gurgling face', 1),
#  ('Buck Mulligan peeped an instant under the', 1),
#  ('Mulligan peeped an instant under the mirror', 1),
#  ('peeped an instant under the mirror and', 1),
#  ('an instant under the mirror and then', 1),
#  ('instant under the mirror and then covered', 1),
#  ("He added in a preacher's tone", 1),
#  ('He peered sideways up and gave a', 1),
#  ('peered sideways up and gave a long', 1),
#  ('sideways up and gave a long slow', 1),
#  ('up and gave a long slow whistle', 1),
#  ('and gave a long slow whistle of', 1),
#  ('gave a long slow whistle of call', 1),
#  ('his even white teeth glistening here and', 1),
#  ('He skipped off the gunrest and looked', 1),
#  ('skipped off the gunrest and looked gravely', 1),
#  ('off the gunrest and looked gravely at', 1),
#  ('the gunrest and looked gravely at his', 1),
#  ('gunrest and looked gravely at his watcher', 1),
#  ('gathering about his legs the loose folds', 1),
#  ('about his legs the loose folds of', 1),
#  ('his legs the loose folds of his', 1),
#  ('legs the loose folds of his gown', 1),
#  ('face and sullen oval jowl recalled a', 1),
#  ('and sullen oval jowl recalled a prelate', 1),
#  ('A pleasant smile broke quietly over his', 1),
#  ('pleasant smile broke quietly over his lips', 1),
#  ('He pointed his finger in friendly jest', 1),
#  ('pointed his finger in friendly jest and', 1),
#  ('his finger in friendly jest and went', 1),
#  ('finger in friendly jest and went over', 1),
#  ('in friendly jest and went over to', 1),
#  ('friendly jest and went over to the', 1),
#  ('jest and went over to the parapet', 1),
#  ('halfway and sat down on the edge', 1),
#  ('and sat down on the edge of', 1),
#  ('sat down on the edge of the', 1),
#  ('down on the edge of the gunrest', 1),
#  ('dipped the brush in the bowl and', 1),
#  ("Buck Mulligan's gay voice went on", 1),
#  ('Tripping and sunny like the buck himself', 1),
#  ('Will you come if I can get', 1),
#  ('you come if I can get the', 1),
#  ('come if I can get the aunt', 1),
#  ('if I can get the aunt to', 1),
#  ('I can get the aunt to fork', 1),
#  ('can get the aunt to fork out', 1),
#  ('―How long is Haines going to stay', 1),
#  ('long is Haines going to stay in', 1),
#  ('is Haines going to stay in this', 1),
#  ('Haines going to stay in this tower', 1),
#  ('Buck Mulligan showed a shaven cheek over', 1),
#  ('Mulligan showed a shaven cheek over his', 1),
#  ('showed a shaven cheek over his right', 1),
#  ('a shaven cheek over his right shoulder', 1),
#  ('―He was raving all night about a', 1),
#  ('was raving all night about a black', 1),
#  ('raving all night about a black panther', 1),
#  ('Stephen said with energy and growing fear', 1),
#  ("with a man I don't know", 1),
#  ("a man I don't know raving", 1),
#  ("man I don't know raving and", 1),
#  ("I don't know raving and moaning", 1),
#  ("don't know raving and moaning to", 1),
#  ("n't know raving and moaning to himself", 1),
#  ('know raving and moaning to himself about', 1),
#  ('raving and moaning to himself about shooting', 1),
#  ('and moaning to himself about shooting a', 1),
#  ('he stays on here I am off', 1),
#  ('Buck Mulligan frowned at the lather on', 1),
#  ('Mulligan frowned at the lather on his', 1),
#  ('frowned at the lather on his razorblade', 1),
#  ('down from his perch and began to', 1),
#  ('from his perch and began to search', 1),
#  ('his perch and began to search his', 1),
#  ('perch and began to search his trouser', 1),
#  ('and began to search his trouser pockets', 1),
#  ('began to search his trouser pockets hastily', 1),
#  ('He came over to the gunrest and', 1),
#  ('―Lend us a loan of your noserag', 1),
#  ('us a loan of your noserag to', 1),
#  ('a loan of your noserag to wipe', 1),
#  ('loan of your noserag to wipe my', 1),
#  ('of your noserag to wipe my razor', 1),
#  ('Stephen suffered him to pull out and', 1),
#  ('suffered him to pull out and hold', 1),
#  ('him to pull out and hold up', 1),
#  ('to pull out and hold up on', 1),
#  ('pull out and hold up on show', 1),
#  ('out and hold up on show by', 1),
#  ('and hold up on show by its', 1),
#  ('hold up on show by its corner', 1),
#  ('up on show by its corner a', 1),
#  ('A new art colour for our Irish', 1),
#  ('new art colour for our Irish poets', 1),
#  ('He mounted to the parapet again and', 1),
#  ('mounted to the parapet again and gazed', 1),
#  ('to the parapet again and gazed out', 1),
#  ('the parapet again and gazed out over', 1),
#  ('parapet again and gazed out over Dublin', 1),
#  ('again and gazed out over Dublin bay', 1),
#  ("Isn't the sea what Algy calls", 1),
#  ("n't the sea what Algy calls it", 1),
#  ('Stephen stood up and went over to', 1),
#  ('stood up and went over to the', 1),
#  ('up and went over to the parapet', 1),
#  ('looked down on the water and on', 1),
#  ('down on the water and on the', 1),
#  ('on the water and on the mailboat', 1),
#  ('the water and on the mailboat clearing', 1),
#  ('water and on the mailboat clearing the', 1),
#  ('and on the mailboat clearing the harbourmouth', 1),
#  ('He turned abruptly his grey searching eyes', 1),
#  ('turned abruptly his grey searching eyes from', 1),
#  ('abruptly his grey searching eyes from the', 1),
#  ('his grey searching eyes from the sea', 1),
#  ('grey searching eyes from the sea to', 1),
#  ('searching eyes from the sea to Stephen', 1),
#  ("eyes from the sea to Stephen's", 1),
#  ('―The aunt thinks you killed your mother', 1),
#  ("That's why she won't let", 1),
#  ('me have anything to do with you', 1),
#  ("I'm hyperborean as much as you", 1),
#  ('think of your mother begging you with', 1),
#  ('of your mother begging you with her', 1),
#  ('your mother begging you with her last', 1),
#  ('mother begging you with her last breath', 1),
#  ('begging you with her last breath to', 1),
#  ('you with her last breath to kneel', 1),
#  ('with her last breath to kneel down', 1),
#  ('her last breath to kneel down and', 1),
#  ('He broke off and lathered again lightly', 1),
#  ('broke off and lathered again lightly his', 1),
#  ('off and lathered again lightly his farther', 1),
#  ('and lathered again lightly his farther cheek', 1),
#  ('an elbow rested on the jagged granite', 1),
#  ('against his brow and gazed at the', 1),
#  ('his brow and gazed at the fraying', 1),
#  ('brow and gazed at the fraying edge', 1),
#  ('and gazed at the fraying edge of', 1),
#  ('gazed at the fraying edge of his', 1),
#  ('at the fraying edge of his shiny', 1),
#  ('the fraying edge of his shiny black', 1),
#  ('fraying edge of his shiny black coatsleeve', 1),
#  ('that was not yet the pain of', 1),
#  ('was not yet the pain of love', 1),
#  ('she had come to him after her', 1),
#  ('had come to him after her death', 1),
#  ('brown graveclothes giving off an odour of', 1),
#  ('Across the threadbare cuffedge he saw the', 1),
#  ('the threadbare cuffedge he saw the sea', 1),
#  ('threadbare cuffedge he saw the sea hailed', 1),
#  ('cuffedge he saw the sea hailed as', 1),
#  ('he saw the sea hailed as a', 1),
#  ('saw the sea hailed as a great', 1),
#  ('the sea hailed as a great sweet', 1),
#  ('mother by the wellfed voice beside him', 1),
#  ('The ring of bay and skyline held', 1),
#  ('ring of bay and skyline held a', 1),
#  ('A bowl of white china had stood', 1),
#  ('bowl of white china had stood beside', 1),
#  ('of white china had stood beside her', 1),
#  ('deathbed holding the green sluggish bile which', 1),
#  ('holding the green sluggish bile which she', 1),
#  ('the green sluggish bile which she had', 1),
#  ('green sluggish bile which she had torn', 1),
#  ('sluggish bile which she had torn up', 1),
#  ('bile which she had torn up from', 1),
#  ('which she had torn up from her', 1),
#  ('rotting liver by fits of loud groaning', 1),
#  ('liver by fits of loud groaning vomiting', 1),
#  ('I must give you a shirt and', 1),
#  ('must give you a shirt and a', 1),
#  ('Buck Mulligan attacked the hollow beneath his', 1),
#  ('Mulligan attacked the hollow beneath his underlip', 1),
#  ('knows what poxy bowsy left them off', 1),
#  ('I have a lovely pair with a', 1),
#  ('have a lovely pair with a hair', 1),
#  ('a lovely pair with a hair stripe', 1),
#  ("I can't wear them if they", 1),
#  ("can't wear them if they are", 1),
#  ("n't wear them if they are grey", 1),
#  ('Buck Mulligan told his face in the', 1),
#  ('Mulligan told his face in the mirror', 1),
#  ('He kills his mother but he ca', 1),
#  ("kills his mother but he can't", 1),
#  ("his mother but he can't wear", 1),
#  ("mother but he can't wear grey", 1),
#  ("but he can't wear grey trousers", 1),
#  ('He folded his razor neatly and with', 1),
#  ('folded his razor neatly and with stroking', 1),
#  ('his razor neatly and with stroking palps', 1),
#  ('razor neatly and with stroking palps of', 1),
#  ('neatly and with stroking palps of fingers', 1),
#  ('and with stroking palps of fingers felt', 1),
#  ('with stroking palps of fingers felt the', 1),
#  ('Stephen turned his gaze from the sea', 1),
#  ('turned his gaze from the sea and', 1),
#  ('his gaze from the sea and to', 1),
#  ('gaze from the sea and to the', 1),
#  ('from the sea and to the plump', 1),
#  ('the sea and to the plump face', 1),
#  ('sea and to the plump face with', 1),
#  ('and to the plump face with its', 1),
#  ('―That fellow I was with in the', 1),
#  ('fellow I was with in the Ship', 1),
#  ('I was with in the Ship last', 1),
#  ('was with in the Ship last night', 1),
#  ("you have g. p. i. He's", 1),
#  ("have g. p. i. He's up", 1),
#  ("g. p. i. He's up in", 1),
#  ("p. i. He's up in Dottyville", 1),
#  ("i. He's up in Dottyville with", 1),
#  ("He's up in Dottyville with Connolly", 1),
#  ("'s up in Dottyville with Connolly Norman", 1),
#  ('He swept the mirror a half circle', 1),
#  ('swept the mirror a half circle in', 1),
#  ('the mirror a half circle in the', 1),
#  ('mirror a half circle in the air', 1),
#  ('a half circle in the air to', 1),
#  ('half circle in the air to flash', 1),
#  ('circle in the air to flash the', 1),
#  ('in the air to flash the tidings', 1),
#  ('the air to flash the tidings abroad', 1),
#  ('in sunlight now radiant on the sea', 1),
#  ('His curling shaven lips laughed and the', 1),
#  ('Stephen bent forward and peered at the', 1),
#  ('bent forward and peered at the mirror', 1),
#  ('forward and peered at the mirror held', 1),
#  ('and peered at the mirror held out', 1),
#  ('peered at the mirror held out to', 1),
#  ('at the mirror held out to him', 1),
#  ('―I pinched it out of the skivvy', 1),
#  ("pinched it out of the skivvy's", 1),
#  ("it out of the skivvy's room", 1),
#  ('The aunt always keeps plainlooking servants for', 1),
#  ('aunt always keeps plainlooking servants for Malachi', 1),
#  ('he brought the mirror away from Stephen', 1),
#  ("brought the mirror away from Stephen's", 1),
#  ("the mirror away from Stephen's peering", 1),
#  ('―The rage of Caliban at not seeing', 1),
#  ('rage of Caliban at not seeing his', 1),
#  ('of Caliban at not seeing his face', 1),
#  ('Caliban at not seeing his face in', 1),
#  ('at not seeing his face in a', 1),
#  ('not seeing his face in a mirror', 1),
#  ('―It is a symbol of Irish art', 1),
#  ('Buck Mulligan suddenly linked his arm in', 1),
#  ('Mulligan suddenly linked his arm in Stephen', 1),
#  ("suddenly linked his arm in Stephen's", 1),
#  ("linked his arm in Stephen's and", 1),
#  ("his arm in Stephen's and walked", 1),
#  ("arm in Stephen's and walked with", 1),
#  ('his razor and mirror clacking in the', 1),
#  ('razor and mirror clacking in the pocket', 1),
#  ('and mirror clacking in the pocket where', 1),
#  ('mirror clacking in the pocket where he', 1),
#  ("―It's not fair to tease you", 1),
#  ("'s not fair to tease you like", 1),
#  ('not fair to tease you like that', 1),
#  ('you have more spirit than any of', 1),
#  ('have more spirit than any of them', 1),
#  ('He fears the lancet of my art', 1),
#  ('fears the lancet of my art as', 1),
#  ('the lancet of my art as I', 1),
#  ('lancet of my art as I fear', 1),
#  ('of my art as I fear that', 1),
#  ('my art as I fear that of', 1),
#  ('art as I fear that of his', 1),
#  ('Tell that to the oxy chap downstairs', 1),
#  ("He's stinking with money and thinks", 1),
#  ("'s stinking with money and thinks you", 1),
#  ("stinking with money and thinks you're", 1),
#  ('His old fellow made his tin by', 1),
#  ('old fellow made his tin by selling', 1),
#  ('fellow made his tin by selling jalap', 1),
#  ('made his tin by selling jalap to', 1),
#  ('his tin by selling jalap to Zulus', 1),
#  ('tin by selling jalap to Zulus or', 1),
#  ('if you and I could only work', 1),
#  ('together we might do something for the', 1),
#  ('we might do something for the island', 1),
#  ('―And to think of your having to', 1),
#  ('to think of your having to beg', 1),
#  ('think of your having to beg from', 1),
#  ('of your having to beg from these', 1),
#  ('your having to beg from these swine', 1),
#  ("Why don't you trust me more", 1),
#  ('If he makes any noise here I', 1),
#  ("he makes any noise here I'll", 1),
#  ("makes any noise here I'll bring", 1),
#  ("down Seymour and we'll give him", 1),
#  ("Seymour and we'll give him a", 1),
#  ("and we'll give him a ragging", 1),
#  ("we'll give him a ragging worse", 1),
#  ("'ll give him a ragging worse than", 1),
#  ('give him a ragging worse than they', 1),
#  ('him a ragging worse than they gave', 1),
#  ('a ragging worse than they gave Clive', 1),
#  ('Young shouts of moneyed voices in Clive', 1),
#  ('shouts of moneyed voices in Clive Kempthorpe', 1),
#  ("of moneyed voices in Clive Kempthorpe's", 1),
#  ("moneyed voices in Clive Kempthorpe's rooms", 1),
#  ('ribbons of his shirt whipping the air', 1),
#  ('of his shirt whipping the air he', 1),
#  ('his shirt whipping the air he hops', 1),
#  ('shirt whipping the air he hops and', 1),
#  ('whipping the air he hops and hobbles', 1),
#  ('the air he hops and hobbles round', 1),
#  ('air he hops and hobbles round the', 1),
#  ('he hops and hobbles round the table', 1),
#  ('chased by Ades of Magdalen with the', 1),
#  ('by Ades of Magdalen with the tailor', 1),
#  ("Ades of Magdalen with the tailor's", 1),
#  ("A scared calf's face gilded with", 1),
#  ("scared calf's face gilded with marmalade", 1),
#  ("Don't you play the giddy ox", 1),
#  ("n't you play the giddy ox with", 1),
#  ('you play the giddy ox with me', 1),
#  ('Shouts from the open window startling evening', 1),
#  ('from the open window startling evening in', 1),
#  ('the open window startling evening in the', 1),
#  ('open window startling evening in the quadrangle', 1),
#  ('mower on the sombre lawn watching narrowly', 1),
#  ('on the sombre lawn watching narrowly the', 1),
#  ('the sombre lawn watching narrowly the dancing', 1),
#  ('sombre lawn watching narrowly the dancing motes', 1),
#  ('lawn watching narrowly the dancing motes of', 1),
#  ("There's nothing wrong with him except", 1),
#  ("'s nothing wrong with him except at", 1),
#  ('looking towards the blunt cape of Bray', 1),
#  ('towards the blunt cape of Bray Head', 1),
#  ('the blunt cape of Bray Head that', 1),
#  ('blunt cape of Bray Head that lay', 1),
#  ('cape of Bray Head that lay on', 1),
#  ('the water like the snout of a', 1),
#  ('water like the snout of a sleeping', 1),
#  ('like the snout of a sleeping whale', 1),
#  ('―Do you wish me to tell you', 1),
#  ("He looked in Stephen's face as", 1),
#  ("looked in Stephen's face as he", 1),
#  ("in Stephen's face as he spoke", 1),
#  ('fanning softly his fair uncombed hair and', 1),
#  ('softly his fair uncombed hair and stirring', 1),
#  ('his fair uncombed hair and stirring silver', 1),
#  ('fair uncombed hair and stirring silver points', 1),
#  ('uncombed hair and stirring silver points of', 1),
#  ('―Do you remember the first day I', 1),
#  ('you remember the first day I went', 1),
#  ('remember the first day I went to', 1),
#  ('the first day I went to your', 1),
#  ('first day I went to your house', 1),
#  ('day I went to your house after', 1),
#  ('I went to your house after my', 1),
#  ('went to your house after my mother', 1),
#  ("to your house after my mother's", 1),
#  ('What happened in the name of God', 1),
#  ('and went across the landing to get', 1),
#  ('Your mother and some visitor came out', 1),
#  ('mother and some visitor came out of', 1),
#  ('and some visitor came out of the', 1),
#  ('She asked you who was in your', 1),
#  ('asked you who was in your room', 1),
#  ("it's only Dedalus whose mother is", 1),
#  ("'s only Dedalus whose mother is beastly", 1),
#  ('A flush which made him seem younger', 1),
#  ('flush which made him seem younger and', 1),
#  ('which made him seem younger and more', 1),
#  ('made him seem younger and more engaging', 1),
#  ('him seem younger and more engaging rose', 1),
#  ('seem younger and more engaging rose to', 1),
#  ('He shook his constraint from him nervously', 1),
#  ("your mother's or yours or my", 1),
#  ("mother's or yours or my own", 1),
#  ('I see them pop off every day', 1),
#  ('see them pop off every day in', 1),
#  ('them pop off every day in the', 1),
#  ('pop off every day in the Mater', 1),
#  ('off every day in the Mater and', 1),
#  ('Richmond and cut up into tripes in', 1),
#  ('and cut up into tripes in the', 1),
#  ('cut up into tripes in the dissectingroom', 1),
#  ('pray for your mother on her deathbed', 1),
#  ('for your mother on her deathbed when', 1),
#  ('your mother on her deathbed when she', 1),
#  ('mother on her deathbed when she asked', 1),
#  ('on her deathbed when she asked you', 1),
#  ('you have the cursed jesuit strain in', 1),
#  ('have the cursed jesuit strain in you', 1),
#  ("only it's injected the wrong way", 1),
#  ("To me it's all a mockery", 1),
#  ("me it's all a mockery and", 1),
#  ("it's all a mockery and beastly", 1),
#  ('She calls the doctor sir Peter Teazle', 1),
#  ('calls the doctor sir Peter Teazle and', 1),
#  ('the doctor sir Peter Teazle and picks', 1),
#  ('doctor sir Peter Teazle and picks buttercups', 1),
#  ('sir Peter Teazle and picks buttercups off', 1),
#  ('You crossed her last wish in death', 1),
#  ('crossed her last wish in death and', 1),
#  ('yet you sulk with me because I', 1),
#  ('you sulk with me because I do', 1),
#  ("sulk with me because I don't", 1),
#  ("with me because I don't whinge", 1),
#  ("me because I don't whinge like", 1),
#  ("because I don't whinge like some", 1),
#  ("I don't whinge like some hired", 1),
#  ("don't whinge like some hired mute", 1),
#  ("n't whinge like some hired mute from", 1),
#  ("I didn't mean to offend the", 1),
#  ('wounds which the words had left in', 1),
#  ('which the words had left in his', 1),
#  ('the words had left in his heart', 1),
#  ('―I am not thinking of the offence', 1),
#  ('am not thinking of the offence to', 1),
#  ('not thinking of the offence to my', 1),
#  ('thinking of the offence to my mother', 1),
#  ('Buck Mulligan swung round on his heel', 1),
#  ('He walked off quickly round the parapet', 1),
#  ('gazing over the calm sea towards the', 1),
#  ('over the calm sea towards the headland', 1),
#  ('A voice within the tower called loudly', 1),
#  ('His head halted again for a moment', 1),
#  ('head halted again for a moment at', 1),
#  ('halted again for a moment at the', 1),
#  ('again for a moment at the top', 1),
#  ('for a moment at the top of', 1),
#  ('a moment at the top of the', 1),
#  ('moment at the top of the staircase', 1),
#  ('His head vanished but the drone of', 1),
#  ('head vanished but the drone of his', 1),
#  ('vanished but the drone of his descending', 1),
#  ('but the drone of his descending voice', 1),
#  ('the drone of his descending voice boomed', 1),
#  ('drone of his descending voice boomed out', 1),
#  ('―And no more turn aside and brood', 1),
#  ('Woodshadows floated silently by through the morning', 1),
#  ('floated silently by through the morning peace', 1),
#  ('silently by through the morning peace from', 1),
#  ('by through the morning peace from the', 1),
#  ('Inshore and farther out the mirror of', 1),
#  ('A cloud began to cover the sun', 1),
#  ('cloud began to cover the sun slowly', 1),
#  ('Silent with awe and pity I went', 1),
#  ('with awe and pity I went to', 1),
#  ('She was crying in her wretched bed', 1),
#  ('a gaud of amber beads in her', 1),
#  ('gaud of amber beads in her locked', 1),
#  ('of amber beads in her locked drawer', 1),
#  ('sunny window of her house when she', 1),
#  ('window of her house when she was', 1),
#  ('of her house when she was a', 1),
#  ('her house when she was a girl', 1),
#  ('in the pantomime of Turko the Terrible', 1),
#  ('the pantomime of Turko the Terrible and', 1),
#  ('pantomime of Turko the Terrible and laughed', 1),
#  ('of Turko the Terrible and laughed with', 1),
#  ('Turko the Terrible and laughed with others', 1),
#  ('the Terrible and laughed with others when', 1),
#  ('Terrible and laughed with others when he', 1),
#  ('And no more turn aside and brood', 1),
#  ('Folded away in the memory of nature', 1),
#  ('away in the memory of nature with', 1),
#  ('in the memory of nature with her', 1),
#  ('the memory of nature with her toys', 1),
#  ('Her glass of water from the kitchen', 1),
#  ('glass of water from the kitchen tap', 1),
#  ('of water from the kitchen tap when', 1),
#  ('water from the kitchen tap when she', 1),
#  ('from the kitchen tap when she had', 1),
#  ('for her at the hob on a', 1),
#  ('her at the hob on a dark', 1),
#  ('at the hob on a dark autumn', 1),
#  ('the hob on a dark autumn evening', 1),
#  ('reddened by the blood of squashed lice', 1),
#  ('by the blood of squashed lice from', 1),
#  ('the blood of squashed lice from the', 1),
#  ('blood of squashed lice from the children', 1),
#  ("of squashed lice from the children's", 1),
#  ("squashed lice from the children's shirts", 1),
#  ('loose graveclothes giving off an odour of', 1),
#  ('bent over him with mute secret words', 1),
#  ('Her hoarse loud breath rattling in horror', 1),
#  ('Her eyes on me to strike me', 1),
#  ('eyes on me to strike me down', 1),
#  ('Let me be and let me live', 1),
#  ("Buck Mulligan's voice sang from within", 1),
#  ("Mulligan's voice sang from within the", 1),
#  ("'s voice sang from within the tower", 1),
#  ("still trembling at his soul's cry", 1),
#  ('warm running sunlight and in the air', 1),
#  ('running sunlight and in the air behind', 1),
#  ('sunlight and in the air behind him', 1),
#  ('and in the air behind him friendly', 1),
#  ('in the air behind him friendly words', 1),
#  ('For my sake and for all our', 1),
#  ('―I told him your symbol of Irish', 1),
#  ('told him your symbol of Irish art', 1),
#  ('glorious drunk to astonish the druidy druids', 1),
#  ('He flung up his hands and tramped', 1),
#  ('flung up his hands and tramped down', 1),
#  ('up his hands and tramped down the', 1),
#  ('his hands and tramped down the stone', 1),
#  ('hands and tramped down the stone stairs', 1),
#  ('smelling the clammy slaver of the lather', 1),
#  ('the clammy slaver of the lather in', 1),
#  ('clammy slaver of the lather in which', 1),
#  ('slaver of the lather in which the', 1),
#  ('of the lather in which the brush', 1),
#  ('the lather in which the brush was', 1),
#  ('lather in which the brush was stuck', 1),
#  ('carried the boat of incense then at', 1),
#  ('the boat of incense then at Clongowes', 1),
#  ('In the gloomy domed livingroom of the', 1),
#  ('the gloomy domed livingroom of the tower', 1),
#  ('gloomy domed livingroom of the tower Buck', 1),
#  ('domed livingroom of the tower Buck Mulligan', 1),
#  ("livingroom of the tower Buck Mulligan's", 1),
#  ('gowned form moved briskly to and fro', 1),
#  ('form moved briskly to and fro about', 1),
#  ('moved briskly to and fro about the', 1),
#  ('briskly to and fro about the hearth', 1),
#  ('Two shafts of soft daylight fell across', 1),
#  ('shafts of soft daylight fell across the', 1),
#  ('of soft daylight fell across the flagged', 1),
#  ('and at the meeting of their rays', 1),
#  ('at the meeting of their rays a', 1),
#  ('the meeting of their rays a cloud', 1),
#  ('meeting of their rays a cloud of', 1),
#  ('coalsmoke and fumes of fried grease floated', 1),
#  ('Stephen laid the shavingbowl on the locker', 1),
#  ('went to the doorway and pulled open', 1),
#  ('The key scraped round harshly twice and', 1),
#  ('Stephen haled his upended valise to the', 1),
#  ('haled his upended valise to the table', 1),
#  ('his upended valise to the table and', 1),
#  ('upended valise to the table and sat', 1),
#  ('Buck Mulligan tossed the fry on to', 1),
#  ('Mulligan tossed the fry on to the', 1),
#  ('tossed the fry on to the dish', 1),
#  ('the fry on to the dish beside', 1),
#  ('fry on to the dish beside him', 1),
#  ('he carried the dish and a large', 1),
#  ('carried the dish and a large teapot', 1),
#  ('the dish and a large teapot over', 1),
#  ('dish and a large teapot over to', 1),
#  ('and a large teapot over to the', 1),
#  ('a large teapot over to the table', 1),
#  ('Stephen fetched the loaf and the pot', 1),
#  ('fetched the loaf and the pot of', 1),
#  ('the loaf and the pot of honey', 1),
#  ('loaf and the pot of honey and', 1),
#  ('and the pot of honey and the', 1),
#  ('the pot of honey and the buttercooler', 1),
#  ('Buck Mulligan sat down in a sudden', 1),
#  ('Mulligan sat down in a sudden pet', 1),
#  ('―What sort of a kip is this', 1),
#  ('Haines came in from the doorway and', 1),
#  ('came in from the doorway and said', 1),
#  ('in from the doorway and said quietly', 1),
#  ('―That woman is coming up with the', 1),
#  ('woman is coming up with the milk', 1),
#  ("can't go fumbling at the damned", 1),
#  ("n't go fumbling at the damned eggs", 1),
#  ('He hacked through the fry on the', 1),
#  ('hacked through the fry on the dish', 1),
#  ('through the fry on the dish and', 1),
#  ('the fry on the dish and slapped', 1),
#  ('fry on the dish and slapped it', 1),
#  ('on the dish and slapped it out', 1),
#  ('the dish and slapped it out on', 1),
#  ('―In nomine Patris et Filii et Spiritus', 1),
#  ('nomine Patris et Filii et Spiritus Sancti', 1),
#  ('Haines sat down to pour out the', 1),
#  ('sat down to pour out the tea', 1),
#  ('―When I makes tea I makes tea', 1),
#  ('Buck Mulligan went on hewing and wheedling', 1),
#  ("you don't make them in the", 1),
#  ('He lunged towards his messmates in turn', 1),
#  ('lunged towards his messmates in turn a', 1),
#  ('towards his messmates in turn a thick', 1),
#  ('his messmates in turn a thick slice', 1),
#  ('messmates in turn a thick slice of', 1),
#  ('in turn a thick slice of bread', 1),
#  ('pages of notes about the folk and', 1),
#  ('of notes about the folk and the', 1),
#  ('notes about the folk and the fishgods', 1),
#  ('about the folk and the fishgods of', 1),
#  ('the folk and the fishgods of Dundrum', 1),
#  ('Printed by the weird sisters in the', 1),
#  ('by the weird sisters in the year', 1),
#  ('the weird sisters in the year of', 1),
#  ('weird sisters in the year of the', 1),
#  ('sisters in the year of the big', 1),
#  ('in the year of the big wind', 1),
#  ('He turned to Stephen and asked in', 1),
#  ('turned to Stephen and asked in a', 1),
#  ('to Stephen and asked in a fine', 1),
#  ('Stephen and asked in a fine puzzled', 1),
#  ('and asked in a fine puzzled voice', 1),
#  ("is mother Grogan's tea and water", 1),
#  ("mother Grogan's tea and water pot", 1),
#  ("Grogan's tea and water pot spoken", 1),
#  ("'s tea and water pot spoken of", 1),
#  ('in the Mabinogion or is it in', 1),
#  ('the Mabinogion or is it in the', 1),
#  ('Mabinogion or is it in the Upanishads', 1),
#  ('Buck Mulligan said in the same tone', 1),
#  ('it did not exist in or out', 1),
#  ('did not exist in or out of', 1),
#  ('not exist in or out of the', 1),
#  ("Buck Mulligan's face smiled with delight", 1),
#  ('he said in a finical sweet voice', 1),
#  ('hoarsened rasping voice as he hewed again', 1),
#  ('rasping voice as he hewed again vigorously', 1),
#  ('voice as he hewed again vigorously at', 1),
#  ('as he hewed again vigorously at the', 1),
#  ('he hewed again vigorously at the loaf', 1),
#  ('He crammed his mouth with fry and', 1),
#  ('crammed his mouth with fry and munched', 1),
#  ('his mouth with fry and munched and', 1),
#  ('mouth with fry and munched and droned', 1),
#  ('The doorway was darkened by an entering', 1),
#  ('doorway was darkened by an entering form', 1),
#  ('An old woman came forward and stood', 1),
#  ('old woman came forward and stood by', 1),
#  ('woman came forward and stood by Stephen', 1),
#  ("came forward and stood by Stephen's", 1),
#  ("forward and stood by Stephen's elbow", 1),
#  ('Stephen reached back and took the milkjug', 1),
#  ('reached back and took the milkjug from', 1),
#  ('back and took the milkjug from the', 1),
#  ('and took the milkjug from the locker', 1),
#  ('He watched her pour into the measure', 1),
#  ('watched her pour into the measure and', 1),
#  ('her pour into the measure and thence', 1),
#  ('pour into the measure and thence into', 1),
#  ('into the measure and thence into the', 1),
#  ('the measure and thence into the jug', 1),
#  ('measure and thence into the jug rich', 1),
#  ('Old and secret she had entered from', 1),
#  ('and secret she had entered from a', 1),
#  ('secret she had entered from a morning', 1),
#  ('she had entered from a morning world', 1),
#  ('She praised the goodness of the milk', 1),
#  ('by a patient cow at daybreak in', 1),
#  ('a patient cow at daybreak in the', 1),
#  ('patient cow at daybreak in the lush', 1),
#  ('cow at daybreak in the lush field', 1),
#  ('wrinkled fingers quick at the squirting dugs', 1),
#  ('Silk of the kine and poor old', 1),
#  ('of the kine and poor old woman', 1),
#  ('serving her conqueror and her gay betrayer', 1),
#  ('―If we could live on good food', 1),
#  ('we could live on good food like', 1),
#  ('could live on good food like that', 1),
#  ("we wouldn't have the country full", 1),
#  ("wouldn't have the country full of", 1),
#  ("n't have the country full of rotten", 1),
#  ('have the country full of rotten teeth', 1),
#  ('the country full of rotten teeth and', 1),
#  ('country full of rotten teeth and rotten', 1),
#  ('full of rotten teeth and rotten guts', 1),
#  ('eating cheap food and the streets paved', 1),
#  ('cheap food and the streets paved with', 1),
#  ('food and the streets paved with dust', 1),
#  ('She bows her old head to a', 1),
#  ('bows her old head to a voice', 1),
#  ('To the voice that will shrive and', 1),
#  ('the voice that will shrive and oil', 1),
#  ('voice that will shrive and oil for', 1),
#  ('that will shrive and oil for the', 1),
#  ('will shrive and oil for the grave', 1),
#  ('shrive and oil for the grave all', 1),
#  ('and oil for the grave all there', 1),
#  ('oil for the grave all there is', 1),
#  ('for the grave all there is of', 1),
#  ('the grave all there is of her', 1),
#  ('grave all there is of her but', 1),
#  ('all there is of her but her', 1),
#  ("of man's flesh made not in", 1),
#  ("man's flesh made not in God", 1),
#  ("'s flesh made not in God's", 1),
#  ("flesh made not in God's likeness", 1),
#  ('And to the loud voice that now', 1),
#  ('to the loud voice that now bids', 1),
#  ('the loud voice that now bids her', 1),
#  ('loud voice that now bids her be', 1),
#  ('voice that now bids her be silent', 1),
#  ('that now bids her be silent with', 1),
#  ('Haines spoke to her again a longer', 1),
#  ('spoke to her again a longer speech', 1),
#  ('and he thinks we ought to speak', 1),
#  ('he thinks we ought to speak Irish', 1),
#  ("and I'm ashamed I don't", 1),
#  ("I'm ashamed I don't speak", 1),
#  ("'m ashamed I don't speak the", 1),
#  ("I'm told it's a grand", 1),
#  ("'m told it's a grand language", 1),
#  ("told it's a grand language by", 1),
#  ("it's a grand language by them", 1),
#  ("'s a grand language by them that", 1),
#  ('a grand language by them that knows', 1),
#  ('on her forearm and about to go', 1),
#  ('twos is a shilling and twopence over', 1),
#  ('is a shilling and twopence over and', 1),
#  ('a shilling and twopence over and these', 1),
#  ('having filled his mouth with a crust', 1),
#  ('stretched forth his legs and began to', 1),
#  ('forth his legs and began to search', 1),
#  ('a spoonful of tea colouring faintly the', 1),
#  ('spoonful of tea colouring faintly the thick', 1),
#  ('He passed it along the table towards', 1),
#  ('passed it along the table towards the', 1),
#  ('it along the table towards the old', 1),
#  ('along the table towards the old woman', 1),
#  ('All I can give you I give', 1),
#  ('Stephen laid the coin in her uneager', 1),
#  ('laid the coin in her uneager hand', 1),
#  ('More would be laid at your feet', 1),
#  ('Hurry out to your school kip and', 1),
#  ('out to your school kip and bring', 1),
#  ('to your school kip and bring us', 1),
#  ('Today the bards must drink and junket', 1),
#  ('that every man this day will do', 1),
#  ('every man this day will do his', 1),
#  ('man this day will do his duty', 1),
#  ('that I have to visit your national', 1),
#  ('He turned to Stephen and asked blandly', 1),
#  ('―Is this the day for your monthly', 1),
#  ('this the day for your monthly wash', 1),
#  ('―The unclean bard makes a point of', 1),
#  ('unclean bard makes a point of washing', 1),
#  ('bard makes a point of washing once', 1),
#  ('makes a point of washing once a', 1),
#  ('a point of washing once a month', 1),
#  ('―All Ireland is washed by the gulfstream', 1),
#  ('trickle over a slice of the loaf', 1),
#  ('Haines from the corner where he was', 1),
#  ('from the corner where he was knotting', 1),
#  ('the corner where he was knotting easily', 1),
#  ('corner where he was knotting easily a', 1),
#  ('where he was knotting easily a scarf', 1),
#  ('he was knotting easily a scarf about', 1),
#  ('the loose collar of his tennis shirt', 1),
#  ('loose collar of his tennis shirt spoke', 1),
#  ('―I intend to make a collection of', 1),
#  ('intend to make a collection of your', 1),
#  ('to make a collection of your sayings', 1),
#  ('make a collection of your sayings if', 1),
#  ('a collection of your sayings if you', 1),
#  ('collection of your sayings if you will', 1),
#  ('of your sayings if you will let', 1),
#  ('your sayings if you will let me', 1),
#  ('about the cracked lookingglass of a servant', 1),
#  ('the cracked lookingglass of a servant being', 1),
#  ('cracked lookingglass of a servant being the', 1),
#  ('lookingglass of a servant being the symbol', 1),
#  ('of a servant being the symbol of', 1),
#  ("Buck Mulligan kicked Stephen's foot under", 1),
#  ("Mulligan kicked Stephen's foot under the", 1),
#  ("kicked Stephen's foot under the table", 1),
#  ("Stephen's foot under the table and", 1),
#  ("'s foot under the table and said", 1),
#  ('foot under the table and said with', 1),
#  ('―Wait till you hear him on Hamlet', 1),
#  ('of it when that poor old creature', 1),
#  ('it when that poor old creature came', 1),
#  ('when that poor old creature came in', 1),
#  ('―Would I make any money by it', 1),
#  ('as he took his soft grey hat', 1),
#  ('he took his soft grey hat from', 1),
#  ('took his soft grey hat from the', 1),
#  ('his soft grey hat from the holdfast', 1),
#  ('soft grey hat from the holdfast of', 1),
#  ('―You put your hoof in it now', 1),
#  ('with your lousy leer and your gloomy', 1),
#  ('your lousy leer and your gloomy jesuit', 1),
#  ('lousy leer and your gloomy jesuit jibes', 1),
#  ('Buck Mulligan sighed tragically and laid his', 1),
#  ('Mulligan sighed tragically and laid his hand', 1),
#  ('sighed tragically and laid his hand on', 1),
#  ('tragically and laid his hand on Stephen', 1),
#  ("and laid his hand on Stephen's", 1),
#  ("laid his hand on Stephen's arm", 1),
#  ('In a suddenly changed tone he added', 1),
#  ("―To tell you the God's truth", 1),
#  ("tell you the God's truth I", 1),
#  ("you the God's truth I think", 1),
#  ("the God's truth I think you", 1),
#  ("God's truth I think you're", 1),
#  ("'s truth I think you're right", 1),
#  ("Why don't you play them as", 1),
#  ("don't you play them as I", 1),
#  ("n't you play them as I do", 1),
#  ('gravely ungirdled and disrobed himself of his', 1),
#  ('ungirdled and disrobed himself of his gown', 1),
#  ('He emptied his pockets on to the', 1),
#  ('emptied his pockets on to the table', 1),
#  ('And putting on his stiff collar and', 1),
#  ('putting on his stiff collar and rebellious', 1),
#  ('on his stiff collar and rebellious tie', 1),
#  ('his stiff collar and rebellious tie he', 1),
#  ('stiff collar and rebellious tie he spoke', 1),
#  ('collar and rebellious tie he spoke to', 1),
#  ('and rebellious tie he spoke to them', 1),
#  ('rummaged in his trunk while he called', 1),
#  ('in his trunk while he called for', 1),
#  ('his trunk while he called for a', 1),
#  ('trunk while he called for a clean', 1),
#  ('while he called for a clean handkerchief', 1),
#  ('I want puce gloves and green boots', 1),
#  ('A limp black missile flew out of', 1),
#  ('limp black missile flew out of his', 1),
#  ('black missile flew out of his talking', 1),
#  ('missile flew out of his talking hands', 1),
#  ("―And there's your Latin quarter hat", 1),
#  ('Stephen picked it up and put it', 1),
#  ('picked it up and put it on', 1),
#  ('Resigned he passed out with grave words', 1),
#  ('he passed out with grave words and', 1),
#  ('passed out with grave words and gait', 1),
#  ('pulled to the slow iron door and', 1),
#  ('to the slow iron door and locked', 1),
#  ('He put the huge key in his', 1),
#  ('put the huge key in his inner', 1),
#  ('the huge key in his inner pocket', 1),
#  ('At the foot of the ladder Buck', 1),
#  ('the foot of the ladder Buck Mulligan', 1),
#  ('foot of the ladder Buck Mulligan asked', 1),
#  ('Behind him he heard Buck Mulligan club', 1),
#  ('him he heard Buck Mulligan club with', 1),
#  ('he heard Buck Mulligan club with his', 1),
#  ('heavy bathtowel the leader shoots of ferns', 1),
#  ('bathtowel the leader shoots of ferns or', 1),
#  ('the leader shoots of ferns or grasses', 1),
#  ('―Do you pay rent for this tower', 1),
#  ('―To the secretary of state for war', 1),
#  ('They halted while Haines surveyed the tower', 1),
#  ('halted while Haines surveyed the tower and', 1),
#  ('while Haines surveyed the tower and said', 1),
#  ('Haines surveyed the tower and said at', 1),
#  ('surveyed the tower and said at last', 1),
#  ('Aquinas and the fiftyfive reasons he has', 1),
#  ('and the fiftyfive reasons he has made', 1),
#  ('the fiftyfive reasons he has made out', 1),
#  ('fiftyfive reasons he has made out to', 1),
#  ('reasons he has made out to prop', 1),
#  ('he has made out to prop it', 1),
#  ('has made out to prop it up', 1),
#  ('have a few pints in me first', 1),
#  ('as he pulled down neatly the peaks', 1),
#  ('he pulled down neatly the peaks of', 1),
#  ('We have grown out of Wilde and', 1),
#  ('have grown out of Wilde and paradoxes', 1),
#  ("He proves by algebra that Hamlet's", 1),
#  ("proves by algebra that Hamlet's grandson", 1),
#  ("by algebra that Hamlet's grandson is", 1),
#  ("Shakespeare's grandfather and that he himself", 1),
#  ("'s grandfather and that he himself is", 1),
#  ('grandfather and that he himself is the', 1),
#  ('and that he himself is the ghost', 1),
#  ('that he himself is the ghost of', 1),
#  ('he himself is the ghost of his', 1),
#  ('himself is the ghost of his own', 1),
#  ('Buck Mulligan slung his towel stolewise round', 1),
#  ('Mulligan slung his towel stolewise round his', 1),
#  ('slung his towel stolewise round his neck', 1),
#  ('his towel stolewise round his neck and', 1),
#  ('―The sacred pint alone can unbind the', 1),
#  ('sacred pint alone can unbind the tongue', 1),
#  ('pint alone can unbind the tongue of', 1),
#  ('alone can unbind the tongue of Dedalus', 1),
#  ('Haines explained to Stephen as they followed', 1),
#  ('and these cliffs here remind me somehow', 1),
#  ('these cliffs here remind me somehow of', 1),
#  ('cliffs here remind me somehow of Elsinore', 1),
#  ('Buck Mulligan turned suddenly for an instant', 1),
#  ('Mulligan turned suddenly for an instant towards', 1),
#  ('turned suddenly for an instant towards Stephen', 1),
#  ('suddenly for an instant towards Stephen but', 1),
#  ('In the bright silent instant Stephen saw', 1),
#  ('the bright silent instant Stephen saw his', 1),
#  ('bright silent instant Stephen saw his own', 1),
#  ('silent instant Stephen saw his own image', 1),
#  ('instant Stephen saw his own image in', 1),
#  ('cheap dusty mourning between their gay attires', 1),
#  ('pale as the sea the wind had', 1),
#  ('as the sea the wind had freshened', 1),
#  ('smokeplume of the mailboat vague on the', 1),
#  ('of the mailboat vague on the bright', 1),
#  ('the mailboat vague on the bright skyline', 1),
#  ('mailboat vague on the bright skyline and', 1),
#  ('vague on the bright skyline and a', 1),
#  ('on the bright skyline and a sail', 1),
#  ('the bright skyline and a sail tacking', 1),
#  ('―I read a theological interpretation of it', 1),
#  ('read a theological interpretation of it somewhere', 1),
#  ('The Son striving to be atoned with', 1),
#  ('Son striving to be atoned with the', 1),
#  ('striving to be atoned with the Father', 1),
#  ('Buck Mulligan at once put on a', 1),
#  ('Mulligan at once put on a blithe', 1),
#  ('at once put on a blithe broadly', 1),
#  ('once put on a blithe broadly smiling', 1),
#  ('put on a blithe broadly smiling face', 1),
#  ("moved a doll's head to and", 1),
#  ("a doll's head to and fro", 1),
#  ('the brims of his Panama hat quivering', 1),
#  ('began to chant in a quiet happy', 1),
#  ('to chant in a quiet happy foolish', 1),
#  ('chant in a quiet happy foolish voice', 1),
#  ("―I'm the queerest young fellow that ever", 1),
#  ('the queerest young fellow that ever you', 1),
#  ('queerest young fellow that ever you heard', 1),
#  ('With Joseph the joiner I cannot', 1),
#  ('Joseph the joiner I cannot agree', 1),
#  ("So here's to disciples and Calvary", 1),
#  ('He held up a forefinger of warning', 1),
#  ("―If anyone thinks that I amn't divine", 1),
#  ("He'll get no free drinks when", 1),
#  ("'ll get no free drinks when I", 1),
#  ("get no free drinks when I'm", 1),
#  ("no free drinks when I'm making", 1),
#  ("free drinks when I'm making the", 1),
#  ("drinks when I'm making the wine", 1),
#  ('But have to drink water and wish', 1),
#  ('have to drink water and wish it', 1),
#  ('to drink water and wish it were', 1),
#  ('drink water and wish it were plain', 1),
#  ('That I make when the wine becomes', 1),
#  ('I make when the wine becomes water', 1),
#  ('make when the wine becomes water again', 1),
#  ("He tugged swiftly at Stephen's ashplant", 1),
#  ("tugged swiftly at Stephen's ashplant in", 1),
#  ("swiftly at Stephen's ashplant in farewell", 1),
#  ("at Stephen's ashplant in farewell and", 1),
#  ('forward to a brow of the cliff', 1),
#  ('fluttered his hands at his sides like', 1),
#  ('his hands at his sides like fins', 1),
#  ('hands at his sides like fins or', 1),
#  ('Dick and Harry I rose from the', 1),
#  ('and Harry I rose from the dead', 1),
#  ("What's bred in the bone can", 1),
#  ("'s bred in the bone cannot", 1),
#  ('bred in the bone cannot fail', 1),
#  ('in the bone cannot fail me', 1),
#  ('the bone cannot fail me to', 1),
#  ('bone cannot fail me to fly', 1),
#  ('He capered before them down towards the', 1),
#  ('capered before them down towards the fortyfoot', 1),
#  ('before them down towards the fortyfoot hole', 1),
#  ("Mercury's hat quivering in the fresh", 1),
#  ('wind that bore back to them his', 1),
#  ('that bore back to them his brief', 1),
#  ('bore back to them his brief birdsweet', 1),
#  ('back to them his brief birdsweet cries', 1),
#  ('Still his gaiety takes the harm out', 1),
#  ('his gaiety takes the harm out of', 1),
#  ('gaiety takes the harm out of it', 1),
#  ('Creation from nothing and miracles and a', 1),
#  ('Haines stopped to take out a smooth', 1),
#  ('stopped to take out a smooth silver', 1),
#  ('to take out a smooth silver case', 1),
#  ('take out a smooth silver case in', 1),
#  ('out a smooth silver case in which', 1),
#  ('a smooth silver case in which twinkled', 1),
#  ('smooth silver case in which twinkled a', 1),
#  ...]

# %%
e1tdoc = textacy.Doc(e1doc)

# %%
e1terms = e1tdoc.to_bag_of_terms(ngrams=(1,2,3,4,5,6,7,8,9), as_strings=True, named_entities=False )

# %%
sorted(e1terms.items(), key=(lambda x: x[1]), reverse=True )
# Out:
# [('-PRON-', 912),
#  ('the', 387),
#  ('and', 217),
#  ('a', 209),
#  ('of', 162),
#  ('say', 148),
#  ('to', 141),
#  ('have', 139),
#  ('be', 137),
#  ('in', 118),
#  ('stephen', 92),
#  ('mulligan', 83),
#  ('buck', 73),
#  ('buck mulligan', 71),
#  ('on', 65),
#  ('with', 65),
#  ('not', 65),
#  ('that', 53),
#  ('-PRON- be', 46),
#  ('from', 45),
#  ('haines', 45),
#  ('-PRON- say', 43),
#  ('at', 40),
#  ('in the', 40),
#  ('-PRON- have', 39),
#  ('out', 37),
#  ('for', 37),
#  ('of -PRON-', 36),
#  ('up', 34),
#  ('do', 34),
#  ('of the', 32),
#  ('come', 29),
#  ('down', 29),
#  ('to -PRON-', 28),
#  ('stephen say', 28),
#  ('mulligan say', 25),
#  ('all', 24),
#  ('over', 24),
#  ('go', 24),
#  ('by', 24),
#  ('can', 23),
#  ('―i', 23),
#  ('ask', 23),
#  ('from the', 23),
#  ('make', 22),
#  ('old', 22),
#  ('will', 21),
#  ('mother', 21),
#  ('in -PRON-', 21),
#  ('buck mulligan say', 21),
#  ('voice', 20),
#  ('do not', 20),
#  ('again', 19),
#  ('on the', 19),
#  ('to the', 19),
#  ('kinch', 18),
#  ('what', 18),
#  ('speak', 18),
#  ('sea', 17),
#  ('turn', 17),
#  ('face', 16),
#  ('about', 16),
#  ('there', 16),
#  ('think', 16),
#  ('hand', 16),
#  ('water', 16),
#  ('have a', 16),
#  ('be -PRON-', 16),
#  ('on -PRON-', 16),
#  ('with -PRON-', 16),
#  ('this', 15),
#  ('sir', 15),
#  ('at the', 15),
#  ('-PRON- do', 15),
#  ('call', 14),
#  ('two', 14),
#  ('―the', 14),
#  ('god', 14),
#  ('when', 14),
#  ('or', 14),
#  ('in a', 14),
#  ('a -PRON-', 14),
#  ('not -PRON-', 14),
#  ('and -PRON-', 14),
#  ('eye', 13),
#  ('one', 13),
#  ('much', 13),
#  ('now', 13),
#  ('be not', 13),
#  ('haines say', 13),
#  ('look', 12),
#  ('like', 12),
#  ('give', 12),
#  ('here', 12),
#  ('off', 12),
#  ('but', 12),
#  ('woman', 12),
#  ('for -PRON-', 12),
#  ('the sea', 12),
#  ('-PRON- will', 12),
#  ('of a', 12),
#  ('morning', 11),
#  ('hold', 11),
#  ('then', 11),
#  ('towards', 11),
#  ('answer', 11),
#  ('cry', 11),
#  ('see', 11),
#  ('and the', 11),
#  ('-PRON- can', 11),
#  ('can not', 11),
#  ('stephen have', 11),
#  ('-PRON- -PRON-', 11),
#  ('-PRON- mother', 11),
#  ('-PRON- do not', 11),
#  ('mirror', 10),
#  ('where', 10),
#  ('man', 10),
#  ('stand', 10),
#  ('tell', 10),
#  ('day', 10),
#  ('tea', 10),
#  ('word', 10),
#  ('at -PRON-', 10),
#  ('from -PRON-', 10),
#  ('out of', 10),
#  ('round', 9),
#  ('tower', 9),
#  ('long', 9),
#  ('know', 9),
#  ('into', 9),
#  ('walk', 9),
#  ('want', 9),
#  ('hear', 9),
#  ('be the', 9),
#  ('to stephen', 9),
#  ('which', 8),
#  ('dedalus', 8),
#  ('head', 8),
#  ('laugh', 8),
#  ('sit', 8),
#  ('get', 8),
#  ('gaze', 8),
#  ('good', 8),
#  ('only', 8),
#  ('some', 8),
#  ('key', 8),
#  ('milk', 8),
#  ('take', 8),
#  ('father', 8),
#  ('and a', 8),
#  ('-PRON- come', 8),
#  ('over -PRON-', 8),
#  ('-PRON- to', 8),
#  ('when -PRON-', 8),
#  ('and say', 8),
#  ('-PRON- hand', 8),
#  ('old woman', 8),
#  ('say to', 8),
#  ('air', 7),
#  ('wind', 7),
#  ('bend', 7),
#  ('o', 7),
#  ('white', 7),
#  ('smile', 7),
#  ('name', 7),
#  ('if', 7),
#  ('begin', 7),
#  ('irish', 7),
#  ('grey', 7),
#  ('―you', 7),
#  ('who', 7),
#  ('servant', 7),
#  ('bring', 7),
#  ('―and', 7),
#  ('young', 7),
#  ('open', 7),
#  ('own', 7),
#  ("―i'm", 7),
#  ('no', 7),
#  ('-PRON- eye', 7),
#  ('mulligan have', 7),
#  ('think -PRON-', 7),
#  ('by the', 7),
#  ('all -PRON-', 7),
#  ('see -PRON-', 7),
#  ('be a', 7),
#  ('for a', 7),
#  ('have -PRON-', 7),
#  ('-PRON- own', 7),
#  ('do -PRON-', 7),
#  ('the old', 7),
#  ('-PRON- have a', 7),
#  ('bowl', 6),
#  ('halt', 6),
#  ('forward', 6),
#  ('arm', 6),
#  ('light', 6),
#  ('hair', 6),
#  ('point', 6),
#  ('art', 6),
#  ('parapet', 6),
#  ('follow', 6),
#  ('must', 6),
#  ('lay', 6),
#  ('money', 6),
#  ('black', 6),
#  ('pocket', 6),
#  ('bay', 6),
#  ('sweet', 6),
#  ('why', 6),
#  ('let', 6),
#  ('damn', 6),
#  ('last', 6),
#  ('green', 6),
#  ('shirt', 6),
#  ('feel', 6),
#  ('―that', 6),
#  ('back', 6),
#  ('―it', 6),
#  ('table', 6),
#  ('―do', 6),
#  ('rise', 6),
#  ('mean', 6),
#  ('door', 6),
#  ('drink', 6),
#  ('doorway', 6),
#  ('wait', 6),
#  ('pour', 6),
#  ('the tower', 6),
#  ('the mirror', 6),
#  ('over to', 6),
#  ('the parapet', 6),
#  ('sit down', 6),
#  ('go to', 6),
#  ('begin to', 6),
#  ('not a', 6),
#  ('-PRON- out', 6),
#  ('-PRON- in', 6),
#  ('-PRON- a', 6),
#  ('-PRON- turn', 6),
#  ('give -PRON-', 6),
#  ('tell -PRON-', 6),
#  ('-PRON- ask', 6),
#  ('a servant', 6),
#  ('where -PRON-', 6),
#  ('-PRON- up', 6),
#  ('-PRON- make', 6),
#  ('the table', 6),
#  ('with the', 6),
#  ('towards the', 6),
#  ('-PRON- go', 6),
#  ('-PRON- call', 6),
#  ('speak to', 6),
#  ('buck mulligan have', 6),
#  ('-PRON- can not', 6),
#  ('the old woman', 6),
#  ('lather', 5),
#  ('behind', 5),
#  ('dark', 5),
#  ('body', 5),
#  ('loose', 5),
#  ('quietly', 5),
#  ('mockery', 5),
#  ('cheek', 5),
#  ('too', 5),
#  ('malachi', 5),
#  ('shave', 5),
#  ('―yes', 5),
#  ('night', 5),
#  ('trouser', 5),
#  ('brow', 5),
#  ('after', 5),
#  ('death', 5),
#  ('across', 5),
#  ('suddenly', 5),
#  ('―o', 5),
#  ('―are', 5),
#  ('brood', 5),
#  ('fill', 5),
#  ('stone', 5),
#  ('time', 5),
#  ('three', 5),
#  ('madam', 5),
#  ('pint', 5),
#  ('put', 5),
#  ('before', 5),
#  ('path', 5),
#  ('behind -PRON-', 5),
#  ('-PRON- and', 5),
#  ('the air', 5),
#  ('and go', 5),
#  ('if -PRON-', 5),
#  ('-PRON- think', 5),
#  ('―i be', 5),
#  ('say with', 5),
#  ('by -PRON-', 5),
#  ('the water', 5),
#  ('ask -PRON-', 5),
#  ('stephen answer', 5),
#  ('have to', 5),
#  ('―do -PRON-', 5),
#  ('down to', 5),
#  ('―are -PRON-', 5),
#  ('-PRON- want', 5),
#  ('the key', 5),
#  ('come in', 5),
#  ('that -PRON-', 5),
#  ('over to the', 5),
#  ('-PRON- be not', 5),
#  ('think -PRON- be', 5),
#  ('do not -PRON-', 5),
#  ('plump', 4),
#  ('razor', 4),
#  ('lie', 4),
#  ('peer', 4),
#  ('jesuit', 4),
#  ('gunrest', 4),
#  ('gravely', 4),
#  ('shake', 4),
#  ('under', 4),
#  ('tone', 4),
#  ('slow', 4),
#  ('tooth', 4),
#  ('through', 4),
#  ('break', 4),
#  ('lip', 4),
#  ('finger', 4),
#  ('watch', 4),
#  ('still', 4),
#  ('quid', 4),
#  ('care', 4),
#  ('love', 4),
#  ('right', 4),
#  ('well', 4),
#  ('―he', 4),
#  ('search', 4),
#  ('pull', 4),
#  ('bard', 4),
#  ('kneel', 4),
#  ('breath', 4),
#  ('pray', 4),
#  ('lovely', 4),
#  ('yet', 4),
#  ('within', 4),
#  ('odour', 4),
#  ('beside', 4),
#  ('live', 4),
#  ('loud', 4),
#  ('poor', 4),
#  ('should', 4),
#  ('leave', 4),
#  ('fellow', 4),
#  ('room', 4),
#  ('away', 4),
#  ('symbol', 4),
#  ('nothing', 4),
#  ('quite', 4),
#  ('free', 4),
#  ('remember', 4),
#  ('―what', 4),
#  ('idea', 4),
#  ('seem', 4),
#  ('would', 4),
#  ('suppose', 4),
#  ('memory', 4),
#  ('very', 4),
#  ('foot', 4),
#  ('sing', 4),
#  ('alone', 4),
#  ('secret', 4),
#  ('pay', 4),
#  ('kip', 4),
#  ('fry', 4),
#  ('locker', 4),
#  ('loaf', 4),
#  ('et', 4),
#  ('eat', 4),
#  ('whom', 4),
#  ('cup', 4),
#  ('twopence', 4),
#  ('side', 4),
#  ('along', 4),
#  ('chant', 4),
#  ('wash', 4),
#  ('hat', 4),
#  ('son', 4),
#  ('down the', 4),
#  ('-PRON- head', 4),
#  ('-PRON- arm', 4),
#  ('up and', 4),
#  ('through the', 4),
#  ('will -PRON-', 4),
#  ('-PRON- must', 4),
#  ('make -PRON-', 4),
#  ('with a', 4),
#  ('over the', 4),
#  ('call -PRON-', 4),
#  ('that have', 4),
#  ('kneel down', 4),
#  ('-PRON- last', 4),
#  ('-PRON- all', 4),
#  ('that be', 4),
#  ('odour of', 4),
#  ('say in', 4),
#  ('out to', 4),
#  ('symbol of', 4),
#  ('―it have', 4),
#  ('for the', 4),
#  ('have face', 4),
#  ('to be', 4),
#  ('there have', 4),
#  ('mulligan ask', 4),
#  ('mulligan answer', 4),
#  ('what do', 4),
#  ('-PRON- seem', 4),
#  ('-PRON- suppose', 4),
#  ('say -PRON-', 4),
#  ('-PRON- walk', 4),
#  ('a voice', 4),
#  ('stephen and', 4),
#  ('-PRON- hear', 4),
#  ('on a', 4),
#  ('-PRON- down', 4),
#  ('let -PRON-', 4),
#  ('-PRON- mean', 4),
#  ('about the', 4),
#  ('the doorway', 4),
#  ('-PRON- the', 4),
#  ('the loaf', 4),
#  ('turn to', 4),
#  ('be to', 4),
#  ('to haines', 4),
#  ('into the', 4),
#  ('walk on', 4),
#  ('the father', 4),
#  ('before -PRON-', 4),
#  ('in the air', 4),
#  ('out of the', 4),
#  ('of a servant', 4),
#  ('-PRON- be the', 4),
#  ('buck mulligan ask', 4),
#  ('buck mulligan answer', 4),
#  ('what do -PRON-', 4),
#  ('-PRON- turn to', 4),
#  ('turn to stephen', 4),
#  ('say to haines', 4),
#  ('speak to -PRON-', 4),
#  ('out of -PRON-', 4),
#  ('-PRON- turn to stephen', 4),
#  ('stairhead', 3),
#  ('cross', 3),
#  ('bless', 3),
#  ('lean', 3),
#  ('staircase', 3),
#  ('pale', 3),
#  ('instant', 3),
#  ('add', 3),
#  ('soul', 3),
#  ('moment', 3),
#  ('silence', 3),
#  ('even', 3),
#  ('strong', 3),
#  ('―thank', 3),
#  ('leg', 3),
#  ('fold', 3),
#  ('gown', 3),
#  ('absurd', 3),
#  ('edge', 3),
#  ('brush', 3),
#  ('gay', 3),
#  ('ring', 3),
#  ('aunt', 3),
#  ('aside', 3),
#  ('delight', 3),
#  ('stay', 3),
#  ('show', 3),
#  ('shoulder', 3),
#  ('english', 3),
#  ('because', 3),
#  ('―a', 3),
#  ('grow', 3),
#  ('fear', 3),
#  ('shoot', 3),
#  ('razorblade', 3),
#  ('noserag', 3),
#  ('wipe', 3),
#  ('handkerchief', 3),
#  ('neatly', 3),
#  ('colour', 3),
#  ('fair', 3),
#  ('great', 3),
#  ('kill', 3),
#  ('anything', 3),
#  ('beg', 3),
#  ('far', 3),
#  ('against', 3),
#  ('pain', 3),
#  ('heart', 3),
#  ('silently', 3),
#  ('brown', 3),
#  ('upon', 3),
#  ('mute', 3),
#  ('how', 3),
#  ('enough', 3),
#  ('dress', 3),
#  ('wear', 3),
#  ('laughter', 3),
#  ('―look', 3),
#  ('crack', 3),
#  ('other', 3),
#  ('any', 3),
#  ('wrong', 3),
#  ('shout', 3),
#  ('heel', 3),
#  ('wish', 3),
#  ('pass', 3),
#  ('\ufeff1', 3),
#  ('house', 3),
#  ('forget', 3),
#  ('beastly', 3),
#  ('way', 3),
#  ('till', 3),
#  ('offence', 3),
#  ('―of', 3),
#  ('dim', 3),
#  ('loudly', 3),
#  ('bitter', 3),
#  ('silent', 3),
#  ('lock', 3),
#  ('girl', 3),
#  ('sugar', 3),
#  ('while', 3),
#  ('te', 3),
#  ('near', 3),
#  ('ready', 3),
#  ('sake', 3),
#  ('―if', 3),
#  ('merry', 3),
#  ('wine', 3),
#  ('coronation', 3),
#  ('so', 3),
#  ('form', 3),
#  ('move', 3),
#  ('soft', 3),
#  ("―we'll", 3),
#  ('bright', 3),
#  ('enter', 3),
#  ('dish', 3),
#  ('sigh', 3),
#  ('bread', 3),
#  ('honey', 3),
#  ('pot', 3),
#  ('hew', 3),
#  ('thick', 3),
#  ('slice', 3),
#  ('grogan', 3),
#  ('mouth', 3),
#  ('an', 3),
#  ('―to', 3),
#  ('quart', 3),
#  ('ought', 3),
#  ('ireland', 3),
#  ('shilling', 3),
#  ('today', 3),
#  ('hamlet', 3),
#  ('―there', 3),
#  ('ashplant', 3),
#  ('rather', 3),
#  ('cliff', 3),
#  ('sense', 3),
#  ('goodbye', 3),
#  ('believer', 3),
#  ('church', 3),
#  ('boatman', 3),
#  ('spur', 3),
#  ('rock', 3),
#  ('bowl of', 3),
#  ('-PRON- on', 3),
#  ('-PRON- hold', 3),
#  ('hold the', 3),
#  ('the bowl', 3),
#  ('the dark', 3),
#  ('come forward', 3),
#  ('forward and', 3),
#  ('-PRON- face', 3),
#  ('stephen dedalus', 3),
#  ('the staircase', 3),
#  ('and look', 3),
#  ('-PRON- cry', 3),
#  ('the gunrest', 3),
#  ('about -PRON-', 3),
#  ('go over', 3),
#  ('edge of', 3),
#  ('the brush', 3),
#  ('go on', 3),
#  ('but -PRON-', 3),
#  ('have not', 3),
#  ('lay the', 3),
#  ('aside and', 3),
#  ('with delight', 3),
#  ('say quietly', 3),
#  ('this tower', 3),
#  ('with money', 3),
#  ('-PRON- know', 3),
#  ('have the', 3),
#  ('here -PRON-', 3),
#  ('-PRON- trouser', 3),
#  ('-PRON- razor', 3),
#  ('great sweet', 3),
#  ('stand up', 3),
#  ('water and', 3),
#  ('kill -PRON-', 3),
#  ('will not', 3),
#  ('think of', 3),
#  ('there be', 3),
#  ('a lovely', 3),
#  ('against -PRON-', 3),
#  ('-PRON- heart', 3),
#  ('after -PRON-', 3),
#  ('across the', 3),
#  ('beside -PRON-', 3),
#  ('up from', 3),
#  ('-PRON- should', 3),
#  ('not wear', 3),
#  ('stephen turn', 3),
#  ('-PRON- gaze', 3),
#  ('and to', 3),
#  ('last night', 3),
#  ('―look at', 3),
#  ('by a', 3),
#  ('-PRON- bring', 3),
#  ('irish art', 3),
#  ('round the', 3),
#  ('what have', 3),
#  ('want to', 3),
#  ('what be', 3),
#  ('-PRON- now', 3),
#  ('mother have', 3),
#  ('make tea', 3),
#  ('be in', 3),
#  ('till -PRON-', 3),
#  ('the word', 3),
#  ('stand at', 3),
#  ('-PRON- feel', 3),
#  ('want -PRON-', 3),
#  ('up the', 3),
#  ('out the', 3),
#  ('the bay', 3),
#  ('hear -PRON-', 3),
#  ('mulligan cry', 3),
#  ('bring -PRON-', 3),
#  ('the locker', 3),
#  ('when the', 3),
#  ('the dish', 3),
#  ('and this', 3),
#  ('mother grogan', 3),
#  ('take the', 3),
#  ('to a', 3),
#  ('woman say', 3),
#  ('-PRON- from', 3),
#  ('-PRON- that', 3),
#  ('a shilling', 3),
#  ('along the', 3),
#  ('put -PRON-', 3),
#  ('―there have', 3),
#  ('haines ask', 3),
#  ('the wind', 3),
#  ('the son', 3),
#  ('young man', 3),
#  ('spur of', 3),
#  ('go over to', 3),
#  ('to the parapet', 3),
#  ('be not -PRON-', 3),
#  ('be not a', 3),
#  ('stephen say with', 3),
#  ('-PRON- in the', 3),
#  ('-PRON- be -PRON-', 3),
#  ('from the sea', 3),
#  ('say in a', 3),
#  ('when -PRON- be', 3),
#  ('can not wear', 3),
#  ('-PRON- ask -PRON-', 3),
#  ('in -PRON- eye', 3),
#  ('-PRON- mother have', 3),
#  ('buck mulligan cry', 3),
#  ('-PRON- the key', 3),
#  ('to the table', 3),
#  ('to stephen and', 3),
#  ('-PRON- think -PRON-', 3),
#  ('say to -PRON-', 3),
#  ('old woman say', 3),
#  ('-PRON- from the', 3),
#  ('-PRON- call -PRON-', 3),
#  ('-PRON- be not a', 3),
#  ('turn to stephen and', 3),
#  ('the old woman say', 3),
#  ('-PRON- turn to stephen and', 3),
#  ('bear', 2),
#  ('yellow', 2),
#  ('ungirdled', 2),
#  ('sustain', 2),
#  ('gently', 2),
#  ('stair', 2),
#  ('coarse', 2),
#  ('―come', 2),
#  ('solemnly', 2),
#  ('mount', 2),
#  ('land', 2),
#  ('sight', 2),
#  ('gurgle', 2),
#  ('top', 2),
#  ('coldly', 2),
#  ('cover', 2),
#  ('―for', 2),
#  ('blood', 2),
#  ('music', 2),
#  ('little', 2),
#  ('whistle', 2),
#  ('awhile', 2),
#  ('glisten', 2),
#  ('calm', 2),
#  ('chap', 2),
#  ('briskly', 2),
#  ('shadow', 2),
#  ('recall', 2),
#  ('middle', 2),
#  ('pleasant', 2),
#  ('friendly', 2),
#  ('prop', 2),
#  ('neck', 2),
#  ('―my', 2),
#  ('sunny', 2),
#  ('―how', 2),
#  ('―god', 2),
#  ('dreadful', 2),
#  ('saxon', 2),
#  ('gentleman', 2),
#  ('bloody', 2),
#  ('oxford', 2),
#  ('rave', 2),
#  ('panther', 2),
#  ('save', 2),
#  ('drown', 2),
#  ('frown', 2),
#  ('hop', 2),
#  ('thickly', 2),
#  ('thrust', 2),
#  ('corner', 2),
#  ('new', 2),
#  ('snotgreen', 2),
#  ('stir', 2),
#  ('ah', 2),
#  ('read', 2),
#  ('thalatta', 2),
#  ('mailboat', 2),
#  ('―our', 2),
#  ('something', 2),
#  ('lightly', 2),
#  ('curl', 2),
#  ('mummer', 2),
#  ('elbow', 2),
#  ('dream', 2),
#  ('waste', 2),
#  ('graveclothe', 2),
#  ('wax', 2),
#  ('rosewood', 2),
#  ('faint', 2),
#  ('wet', 2),
#  ('ash', 2),
#  ('skyline', 2),
#  ('mass', 2),
#  ('deathbed', 2),
#  ('fit', 2),
#  ('―ah', 2),
#  ('dogsbody', 2),
#  ('few', 2),
#  ('beneath', 2),
#  ('underlip', 2),
#  ('joke', 2),
#  ('etiquette', 2),
#  ('stroke', 2),
#  ('smooth', 2),
#  ('ship', 2),
#  ('sweep', 2),
#  ('half', 2),
#  ('sunlight', 2),
#  ('trunk', 2),
#  ('doe', 2),
#  ('always', 2),
#  ('keep', 2),
#  ('wilde', 2),
#  ('lookingglass', 2),
#  ('than', 2),
#  ('cold', 2),
#  ('touch', 2),
#  ('guinea', 2),
#  ('seymour', 2),
#  ('clive', 2),
#  ('kempthorpe', 2),
#  ('rib', 2),
#  ('another', 2),
#  ('shall', 2),
#  ('die', 2),
#  ('play', 2),
#  ('window', 2),
#  ('omphalos', 2),
#  ('sleep', 2),
#  ('silver', 2),
#  ('quickly', 2),
#  ('dead', 2),
#  ('―did', 2),
#  ('harm', 2),
#  ('every', 2),
#  ('thing', 2),
#  ('else', 2),
#  ('simply', 2),
#  ('pick', 2),
#  ('shield', 2),
#  ('headland', 2),
#  ('chuck', 2),
#  ('drone', 2),
#  ('mystery', 2),
#  ('fergus', 2),
#  ('brazen', 2),
#  ('float', 2),
#  ('spurn', 2),
#  ('hurry', 2),
#  ('twine', 2),
#  ('chord', 2),
#  ('tide', 2),
#  ('cloud', 2),
#  ('sun', 2),
#  ('slowly', 2),
#  ('deep', 2),
#  ('bed', 2),
#  ('liliata', 2),
#  ('rutilantium', 2),
#  ('turma', 2),
#  ('circumdet', 2),
#  ('iubilantium', 2),
#  ('virginum', 2),
#  ('―kinch', 2),
#  ('warm', 2),
#  ('run', 2),
#  ('―dedalus', 2),
#  ('breakfast', 2),
#  ('wake', 2),
#  ('jesus', 2),
#  ('school', 2),
#  ('four', 2),
#  ('shine', 2),
#  ('sovereign', 2),
#  ('fling', 2),
#  ('singe', 2),
#  ('nickel', 2),
#  ('shavingbowl', 2),
#  ('carry', 2),
#  ('same', 2),
#  ('gloomy', 2),
#  ('fro', 2),
#  ('fall', 2),
#  ('meet', 2),
#  ('choke', 2),
#  ('hammock', 2),
#  ('inner', 2),
#  ('―have', 2),
#  ('heavy', 2),
#  ('set', 2),
#  ('toss', 2),
#  ('butter', 2),
#  ('lord', 2),
#  ('―we', 2),
#  ('wheedle', 2),
#  ('mrs', 2),
#  ('cahill', 2),
#  ('folk', 2),
#  ('five', 2),
#  ('line', 2),
#  ('brother', 2),
#  ('mabinogion', 2),
#  ('reason', 2),
#  ('mary', 2),
#  ('ann', 2),
#  ('blink', 2),
#  ('jug', 2),
#  ('glance', 2),
#  ('sure', 2),
#  ('reach', 2),
#  ('measure', 2),
#  ('rich', 2),
#  ('messenger', 2),
#  ('serve', 2),
#  ('whether', 2),
#  ('bid', 2),
#  ('food', 2),
#  ('country', 2),
#  ('rotten', 2),
#  ('cheap', 2),
#  ('grave', 2),
#  ('unclean', 2),
#  ('understand', 2),
#  ('french', 2),
#  ('talk', 2),
#  ('language', 2),
#  ('wonderful', 2),
#  ('―no', 2),
#  ('seven', 2),
#  ('forth', 2),
#  ('3', 2),
#  ('miracle', 2),
#  ('coin', 2),
#  ('remind', 2),
#  ('national', 2),
#  ('once', 2),
#  ('collar', 2),
#  ('―well', 2),
#  ('just', 2),
#  ('hoof', 2),
#  ('problem', 2),
#  ('blow', 2),
#  ('change', 2),
#  ('empty', 2),
#  ('tie', 2),
#  ('plunge', 2),
#  ('clean', 2),
#  ('boot', 2),
#  ('contradict', 2),
#  ('fly', 2),
#  ('ladder', 2),
#  ('―down', 2),
#  ('rend', 2),
#  ('state', 2),
#  ('war', 2),
#  ('could', 2),
#  ('paradox', 2),
#  ('somehow', 2),
#  ('sail', 2),
#  ('gaiety', 2),
#  ('quiver', 2),
#  ('ever', 2),
#  ('joseph', 2),
#  ('joiner', 2),
#  ('flutter', 2),
#  ('brief', 2),
#  ('personal', 2),
#  ('case', 2),
#  ('spring', 2),
#  ('cigarette', 2),
#  ('course', 2),
#  ('either', 2),
#  ('tonight', 2),
#  ('―after', 2),
#  ('master', 2),
#  ('―italian', 2),
#  ('angel', 2),
#  ('disarm', 2),
#  ('menace', 2),
#  ('heresiarch', 2),
#  ('businessman', 2),
#  ('nod', 2),
#  ('creek', 2),
#  ('red', 2),
#  ('scramble', 2),
#  ('―seymour', 2),
#  ('clothe', 2),
#  ('heap', 2),
#  ('throw', 2),
#  ('come from', 2),
#  ('the stairhead', 2),
#  ('lather on', 2),
#  ('a mirror', 2),
#  ('mirror and', 2),
#  ('-PRON- peer', 2),
#  ('come up', 2),
#  ('towards -PRON-', 2),
#  ('shake -PRON-', 2),
#  ('lean -PRON-', 2),
#  ('the top', 2),
#  ('top of', 2),
#  ('bless -PRON-', 2),
#  ('and at', 2),
#  ('a instant', 2),
#  ('under the', 2),
#  ('and then', 2),
#  ('-PRON- add', 2),
#  ('a long', 2),
#  ('white tooth', 2),
#  ('the calm', 2),
#  ('that will', 2),
#  ('will do', 2),
#  ('off the', 2),
#  ('gunrest and', 2),
#  ('-PRON- leg', 2),
#  ('the loose', 2),
#  ('-PRON- gown', 2),
#  ('the plump', 2),
#  ('the middle', 2),
#  ('-PRON- lip', 2),
#  ('―the mockery', 2),
#  ...]

# %%
list(e1terms.items())[50][0]
# Out:
# 'fearful'
